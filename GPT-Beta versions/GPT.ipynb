# %%
# !pip install transformers
# !pip install torch
# !pip instal torch.nn
# Out:
# Requirement already satisfied: transformers in c:\users\mithu\anaconda3\lib\site-packages (5.0.0)
# Requirement already satisfied: filelock in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (1.3.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mithu\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mithu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\mithu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mithu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in c:\users\mithu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\mithu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.12.2)
# Requirement already satisfied: anyio in c:\users\mithu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.7.0)
# Requirement already satisfied: certifi in c:\users\mithu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\mithu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\mithu\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\mithu\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\mithu\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mithu\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\mithu\anaconda3\lib\site-packages (from typer-slim->transformers) (8.1.8)

# %%
import pandas as pd
from transformers import AutoTokenizer
import torch
import torch.nn as nn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
#       2 from transformers import AutoTokenizer
# ----> 3 import torch
#       4 import torch.nn as nn
#
# ModuleNotFoundError: No module named 'torch'

# %%
df=pd.read_csv('Poems_Dataset.csv')
df=df["Poem Content"]
df.head()
# Out:
# 0    The line-storm clouds fly tattered and swift, ...
# 1    Droning a drowsy syncopated tune,\nRocking bac...
# 2    In the burned house I am eating breakfast.\nYo...
# 3    I\nLiving is no laughing matter:\n you must li...
# 4                         Bolinao, Philippines\n I ...
# Name: Poem Content, dtype: object

# %%
data=''.join(df.tolist())
tokenizer=AutoTokenizer.from_pretrained("gpt2")
# Out:
# 19258119
